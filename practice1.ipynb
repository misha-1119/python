# %%
character_name = input("Вітаю! Введіть ім'я вашого персонажа.")
print("Вітаю, " + character_name +
            "! Тобі належить вибрати свій шлях у невеликій грі, в результаті якої ти дізнаєшся який сік компанії Січко™ тобі підходить найбільше!")
# Out:
# Вітаю, 1! Тобі належить вибрати свій шлях у невеликій грі, в результаті якої ти дізнаєшся який сік компанії Січко™ тобі підходить найбільше!

# %%
answers_array = []

quest_index = 0


print("Вітаю на першому рівні! До тебе підходить невідоме створіння, схоже на гнома, і каже:\n'Привіт, незнайомцю. Якщо ти хочеш пройти, то тобі потрібно відгадати загадку. Якщо ти не хочеш, то я тебе вб'ю.'")

print("Варіанти відповідей:\n1) 'Так, я хочу відгадати загадку.'\n2) 'Ні, я не хочу відгадувати загадку. (почати драку)'")

answer = input("Введіть відповідь: ")

answers_array.append(answer)

match answer:
    case "1": delay_print("Гном: 'Добре, тоді почнемо. Якщо ти відгадаєш, то я тобі дам піти.'")
    case "2": delay_print("Гном: 'Ти вирішив битися? Тоді почнемо.'")
    case _: delay_print("Гном: 'Я не розумію тебе. Якщо ти не зможеш відповісти, то я тебе вб'ю.'")
# Out:
# Вітаю на першому рівні! До тебе підходить невідоме створіння, схоже на гнома, і каже:
# 'Привіт, незнайомцю. Якщо ти хочеш пройти, то тобі потрібно відгадати загадку. Якщо ти не хочеш, то я тебе вб'ю.'
# Варіанти відповідей:
# 1) 'Так, я хочу відгадати загадку.'
# 2) 'Ні, я не хочу відгадувати загадку. (почати драку)'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 15
#      12 answers_array.append(answer)
#      14 match answer:
# ---> 15     case "1": delay_print("Гном: 'Добре, тоді почнемо. Якщо ти відгадаєш, то я тобі дам піти.'")
#      16     case "2": delay_print("Гном: 'Ти вирішив битися? Тоді почнемо.'")
#      17     case _: delay_print("Гном: 'Я не розумію тебе. Якщо ти не зможеш відповісти, то я тебе вб'ю.'")
#
# NameError: name 'delay_print' is not defined

# %%
quest_index = 1
previous_answer = answers_array[quest_index - 1]

match previous_answer:
    case "1": 
        print("Гном: 'У мами Івана було три сини. Першого звали Петро, другого – Василь. Як звали третього сина?'")
        print("Варіанти відповідей:\n1) 'Іван'\n2) 'Петро'\n3) 'Василь'")
        answer = input("Введіть відповідь: ")
    case '2':
        print("*Гном розмахується кулаком і ударяє вас по коліну.*")
        print("Гном: 'Н-Н-Н-А-А-А!!!'")
        print("*Ви відчуваєте сильний біль в коліні але він не надто сильний*\n1. *пнути гнома з усієї сили ногою*\n2. Будь ласка!!! Не бий! Я відповім на твою загадку!!!")
        answer = input("Введіть відповідь: ")
    case _:
        print("Гном: 'Шо ти там бормочеш??!!'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 6
#       4 match previous_answer:
#       5     case "1":
# ----> 6         delay_print("Гном: 'У мами Івана було три сини. Першого звали Петро, другого – Василь. Як звали третього сина?'")
#       7         print("Варіанти відповідей:\n1) 'Іван'\n2) 'Петро'\n3) 'Василь'")
#       8         answer = input("Введіть відповідь: ")
#
# NameError: name 'delay_print' is not defined
